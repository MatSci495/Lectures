# %% [markdown]
# # MSE 495 — Module 1 Preparation
# ## A simple simulation: 1,000 coin flips
#
# This short notebook is preparation for our first quantitative module. Its main purpose is to make sure you can open a course notebook in Google Colab, run and edit Python code, and save your own working copy.
#
# Before editing, use **File → Save a copy in Drive** so that you are working in your own copy rather than the released course version.

# %% [markdown]
# ### The task
#
# Write Python code that simulates **1,000 flips of a fair coin**.
#
# Use any reasonable Python approach. Your code should:
#
# 1. generate 1,000 independent outcomes with equal probability of heads and tails;
# 2. count the number of heads; and
# 3. calculate the **fraction of flips that are heads**.
#
# Run the simulation and report the fraction of heads that you obtained.
#
# You do not need to make a plot or perform any statistical analysis. We will build from this simple experiment in class.

# %% [markdown]
# ### Your simulation
#
# If you already know how you want to write the simulation, replace the comment in the cell below with your code.
#
# If Python is unfamiliar, describe in plain language what the code needs to do first, then translate those steps into code. You may use an LLM to help with implementation, but you are responsible for checking that the code actually performs the experiment described above.

# %%
# Write your 1,000-coin-flip simulation here.

# %% [markdown]
# ### Result
#
# **Fraction of heads:** _replace this text with your result_
#
# Before class, make sure that your notebook runs and that you have saved your copy in Google Drive. You do not need to submit this notebook unless Canvas instructs you to do so.
